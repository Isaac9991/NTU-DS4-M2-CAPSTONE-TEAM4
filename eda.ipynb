# %%
# uncomment the following line to install required libraries (only needed for the first run). remember to comment it out again after the 
# first run to avoid unnecessary re-installation in subsequent runs.

# !pip install -r requirements.txt

# %%
#imports
import pandas as pd
import numpy as np
from src.data import *

# %%
# First-time setup (downloads dataset if needed)
dataset_path, _ = first_time_setup()

# %%
# Load all CSVs into a dictionary
data = load_data(dataset_path)
for name, df in data.items():
    print(f"\n=== {name} ===")
    display(df.head())  # use display() in Jupyter for prettier output
